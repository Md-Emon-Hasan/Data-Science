# %%
import numpy as np
import pandas as pd
dict1 = {
    'name' : ['harry','rohan','skillf','shubh'],
    'marks' : [92,34,24,17],
    'city' : ['rampur','kolkata','bareilly','antarctica']
}
df = pd.DataFrame(dict1)
df
# Out:
#      name  marks        city
# 0   harry     92      rampur
# 1   rohan     34     kolkata
# 2  skillf     24    bareilly
# 3   shubh     17  antarctica

# %%
# create dict to csv file
import pandas as pd
import numpy as np
dict1 = {
    'name' : ['harry','rohan','skillf','shubh'],
    'marks' : [92,34,24,17],
    'city' : ['rampur','kolkata','bareilly','antarctica']
}
df = pd.DataFrame(dict1)
df
df.to_csv('friends.csv')

# %%
# create dict to csv file
import pandas as pd
import numpy as np
dict1 = {
    'name' : ['harry','rohan','skillf','shubh'],
    'marks' : [92,34,24,17],
    'city' : ['rampur','kolkata','bareilly','antarctica']
}
df = pd.DataFrame(dict1)
df
df.to_csv('friends_index_false.csv',index=False)

# %%
# for showing first 2 data
import pandas as pd
import numpy as np
dict1 = {
    'name' : ['harry','rohan','skillf','shubh'],
    'marks' : [92,34,24,17],
    'city' : ['rampur','kolkata','bareilly','antarctica']
}
df = pd.DataFrame(dict1)
df.head(2)
# Out:
#     name  marks     city
# 0  harry     92   rampur
# 1  rohan     34  kolkata

# %%
# for showing last two data
import pandas as pd
import numpy as np
dict1 = {
    'name' : ['harry','rohan','skillf','shubh'],
    'marks' : [92,34,24,17],
    'city' : ['rampur','kolkata','bareilly','antarctica']
}
df = pd.DataFrame(dict1)
df.tail(2)
# Out:
#      name  marks        city
# 2  skillf     24    bareilly
# 3   shubh     17  antarctica

# %%
# for describe data
import pandas as pd
import numpy as np
dict1 = {
    'name' : ['harry','rohan','skillf','shubh'],
    'marks' : [92,34,24,17],
    'city' : ['rampur','kolkata','bareilly','antarctica']
}
df = pd.DataFrame(dict1)
df.describe()
# Out:
#           marks
# count   4.00000
# mean   41.75000
# std    34.21866
# min    17.00000
# 25%    22.25000
# 50%    29.00000
# 75%    48.50000
# max    92.00000

# %%
# read data from file
harry = pd.read_csv('friends_index_false.csv')
harry
# Out:
#      name  marks        city
# 0   harry     92      rampur
# 1   rohan     34     kolkata
# 2  skillf     24    bareilly
# 3   shubh     17  antarctica

# %%
harry = pd.read_csv('friends_index_false.csv')
harry['marks']
# Out:
# 0    92
# 1    34
# 2    24
# 3    17
# Name: marks, dtype: int64

# %%
harry = pd.read_csv('friends_index_false.csv')
harry['marks'][0]
# Out:
# 92

# %%
harry = pd.read_csv('friends_index_false.csv')
harry.to_csv('friends_index_false.csv')
harry.index = ['first','second','third','fourth']
harry
# Out:
#           name  marks        city
# first    harry     92      rampur
# second   rohan     34     kolkata
# third   skillf     24    bareilly
# fourth   shubh     17  antarctica

# %% [markdown]
# __series__

# %%
ser = pd.Series(np.random.rand)
ser
# Out:
# 0    <built-in method rand of numpy.random.mtrand.R...
# dtype: object

# %%
ser = pd.Series(np.random.rand(26))
ser
# Out:
# 0     0.781443
# 1     0.156993
# 2     0.903860
# 3     0.554690
# 4     0.779924
# 5     0.489728
# 6     0.527939
# 7     0.898008
# 8     0.467003
# 9     0.352940
# 10    0.791578
# 11    0.898489
# 12    0.795394
# 13    0.593687
# 14    0.298680
# 15    0.871673
# 16    0.161169
# 17    0.840348
# 18    0.318007
# 19    0.542418
# 20    0.495849
# 21    0.538902
# 22    0.860382
# 23    0.655063
# 24    0.634659
# 25    0.600747
# dtype: float64

# %%
ser = pd.Series(np.random.rand(34))
type(ser)
# Out:
# pandas.core.series.Series

# %%
newfd = pd.DataFrame(np.random.rand(334,5),index=np.arange(334))
newfd
# Out:
#             0         1         2         3         4
# 0    0.208299  0.406514  0.469258  0.559834  0.593768
# 1    0.274284  0.038043  0.234059  0.005228  0.434059
# 2    0.431504  0.733230  0.187820  0.209926  0.988939
# 3    0.491942  0.016914  0.567948  0.141453  0.275284
# 4    0.993967  0.716062  0.399225  0.215696  0.375780
# ..        ...       ...       ...       ...       ...
# 329  0.697785  0.695322  0.933021  0.486748  0.867925
# 330  0.979557  0.835393  0.456843  0.003634  0.308365
# 331  0.732388  0.829042  0.110020  0.882302  0.797487
# 332  0.603929  0.569699  0.121458  0.079353  0.019412
# 333  0.266039  0.920859  0.470913  0.298220  0.834470
#
# [334 rows x 5 columns]

# %%
newfd = pd.DataFrame(np.random.rand(334,5),index=np.arange(334))
# %%
newfd = pd.DataFrame(np.random.rand(334,5),index=np.arange(334))
type(newfd[0])
newfd.loc[0,0] = 654
newfd.head(5)
# Out:
#             0         1         2         3         4
# 0  654.000000  0.586748  0.078296  0.290546  0.329621
# 1    0.856457  0.870285  0.386761  0.101241  0.991616
# 2    0.033100  0.207268  0.609608  0.880186  0.556877
# 3    0.990626  0.392682  0.302764  0.835059  0.091938
# 4    0.344438  0.925085  0.338957  0.243064  0.575984

# %%
# change column name
newfd = pd.DataFrame(np.random.rand(334,5),index=np.arange(334))
newfd.columns = list('ABCDE')
newfd.head(5)
# Out:
#           A         B         C         D         E
# 0  0.497073  0.793723  0.389459  0.142877  0.756493
# 1  0.997586  0.659254  0.017003  0.134380  0.433074
# 2  0.385624  0.571394  0.615852  0.840764  0.761424
# 3  0.105242  0.113421  0.463367  0.312790  0.176363
# 4  0.404754  0.005045  0.494440  0.674586  0.314812

# %%
newfd = pd.DataFrame(np.random.rand(334,5),index=np.arange(334))
newfd.columns = list('ABCDE')
newfd.loc[0,'A'] = 654
newfd
# Out:
#               A         B         C         D         E
# 0    654.000000  0.357690  0.325891  0.070552  0.583971
# 1      0.827365  0.907115  0.242750  0.872053  0.760860
# 2      0.641266  0.524096  0.370989  0.226409  0.313913
# 3      0.591174  0.183653  0.665949  0.324997  0.123389
# 4      0.058127  0.149135  0.404448  0.962210  0.182083
# ..          ...       ...       ...       ...       ...
# 329    0.737097  0.061696  0.600184  0.270834  0.989662
# 330    0.696947  0.149061  0.654847  0.353330  0.523662
# 331    0.746474  0.719742  0.001065  0.439908  0.193844
# 332    0.200027  0.167200  0.987570  0.897806  0.609207
# 333    0.682626  0.681627  0.328117  0.467419  0.064887
#
# [334 rows x 5 columns]

# %%
newfd = pd.DataFrame(np.random.rand(334,5),index=np.arange(334))
newfd.columns = list('ABCDE')
newfd = newfd.drop(0,axis=1)
newfd.head()
newfd.loc[[1,2],['C','D']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 3
#       1 newfd = pd.DataFrame(np.random.rand(334,5),index=np.arange(334))
#       2 newfd.columns = list('ABCDE')
# ----> 3 newfd = newfd.drop(0,axis=1)
#       4 newfd.head()
#       5 newfd.loc[[1,2],['C','D']]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
# ...

# %%
newfd = pd.DataFrame(np.random.rand(334,5),index=np.arange(334))
newfd.columns = list('ABCDE')
newfd.loc[[1,2],['C','D']]
# Out:
#           C         D
# 1  0.607297  0.790579
# 2  0.304497  0.046459

# %%
import pandas as pd
import numpy as np
newfd = pd.DataFrame(np.random.rand(334,5),index=np.arange(334))
newfd.columns = list('ABCDE')
newfd.loc[[1,2],:]
# Out:
#           A         B         C         D         E
# 1  0.008129  0.462104  0.126428  0.691233  0.402705
# 2  0.693739  0.226114  0.793323  0.204287  0.302114

# %%
# if condition are true is show the the data otherwise its hide the data
newfd = pd.DataFrame(np.random.rand(334,5),index=np.arange(334))
newfd.loc[(newfd[0]<0.3)]
# Out:
#             0         1         2         3         4
# 0    0.246084  0.367529  0.914454  0.167787  0.122363
# 1    0.188087  0.833001  0.657475  0.468943  0.405256
# 3    0.262758  0.582356  0.739895  0.876562  0.749757
# 6    0.185306  0.038056  0.979280  0.257653  0.739903
# 13   0.230491  0.933322  0.024753  0.243613  0.214544
# ..        ...       ...       ...       ...       ...
# 305  0.165003  0.432315  0.812758  0.264457  0.856119
# 313  0.112203  0.320366  0.730516  0.290802  0.747111
# 318  0.287648  0.200838  0.306252  0.983772  0.079359
# 323  0.164111  0.972212  0.932292  0.651639  0.035829
# 327  0.052524  0.128982  0.089339  0.188126  0.911943
#
# [106 rows x 5 columns]

# %%
newfd = pd.DataFrame(np.random.rand(334,5),index=np.arange(334))
newfd.columns = list('ABCDE')
newfd.loc[(newfd['A']<0.1)]
# Out:
#             A         B         C         D         E
# 18   0.051075  0.880208  0.939832  0.493345  0.098571
# 21   0.094567  0.434437  0.648224  0.451136  0.056322
# 22   0.023610  0.116668  0.880354  0.805216  0.343744
# 36   0.047288  0.324591  0.893329  0.129477  0.321877
# 42   0.049574  0.216594  0.275758  0.591015  0.955737
# 45   0.057333  0.610310  0.273990  0.964200  0.436267
# 70   0.085279  0.074650  0.185100  0.321799  0.606036
newfd = pd.DataFrame(np.random.rand(334,5),index=np.arange(334))
newfd.columns = list('ABCDE')
newfd.drop(['A','D'],axis=1,inplace=True)
newfd
# Out:
#             B         C         E
# 0    0.067934  0.132595  0.727817
# 1    0.056179  0.363856  0.006010
# 2    0.722801  0.940135  0.694731
# 3    0.317823  0.581104  0.873231
# 4    0.977581  0.559575  0.421613
# ..        ...       ...       ...
# 329  0.035580  0.218409  0.767833
# 330  0.571469  0.544244  0.620120
# 331  0.439228  0.878582  0.578843
# 332  0.559409  0.056615  0.834230
# 333  0.881605  0.135501  0.701797
#
# [334 rows x 3 columns]

# %%
# for hide without this element
newfd = pd.DataFrame(np.random.rand(334,5),index=np.arange(334))
newfd.columns = list('ABCDE')
newfd.drop([1,3,5,6,8],axis=0,inplace=True)
newfd
# Out:
#             A         B         C         D         E
# 0    0.821881  0.585869  0.408930  0.103494  0.634851
# 2    0.635338  0.720082  0.905057  0.390055  0.202357
# 4    0.417691  0.439651  0.242787  0.170452  0.093769
# 7    0.932176  0.667614  0.584195  0.046796  0.660194
# 9    0.848201  0.651747  0.386380  0.076933  0.231548
# ..        ...       ...       ...       ...       ...
# 329  0.972692  0.212724  0.151129  0.335204  0.544951
# 330  0.593272  0.325610  0.173511  0.229396  0.847679
# 331  0.311695  0.889169  0.320906  0.215375  0.841552
# 332  0.264710  0.074711  0.697536  0.090779  0.714704
# 333  0.248349  0.129599  0.949798  0.169056  0.914422
#
# [329 rows x 5 columns]

# %%
# for hide without this element
# for indexing reverse
newfd = pd.DataFrame(np.random.rand(334,5),index=np.arange(334))
newfd.columns = list('ABCDE')
newfd.drop([1,3,5,6,8],axis=0,inplace=True)
newfd.reset_index()
# Out:
#      index         A         B         C         D         E
# 0        0  0.278326  0.939022  0.836976  0.383731  0.518106
# 1        2  0.809157  0.130435  0.012550  0.822657  0.858893
# 2        4  0.678379  0.377675  0.243214  0.406632  0.430720
# 3        7  0.147129  0.843532  0.872002  0.265173  0.899926
# 4        9  0.506307  0.528657  0.274196  0.716103  0.788572
# ..     ...       ...       ...       ...       ...       ...
# 324    329  0.696497  0.427282  0.388826  0.118664  0.874850
# 325    330  0.720836  0.683753  0.381570  0.009870  0.942917
# 326    331  0.861345  0.544928  0.520325  0.072311  0.546428
# 327    332  0.797987  0.357341  0.598147  0.610702  0.320295
# 328    333  0.794408  0.571806  0.803903  0.460015  0.399978
#
# [329 rows x 6 columns]

# %%
# for hide without this element
# for indexing reverse
newfd = pd.DataFrame(np.random.rand(334,5),index=np.arange(334))
newfd.columns = list('ABCDE')
newfd.drop([1,3,5,6,8],axis=0,inplace=True)
newfd.reset_index(drop=True)
# Out:
#             A         B         C         D         E
# 0    0.637297  0.911063  0.151062  0.722491  0.405790
# 1    0.887086  0.120068  0.282760  0.942625  0.538001
# 2    0.572306  0.725885  0.928378  0.821886  0.481364
# 3    0.653321  0.563272  0.403776  0.455977  0.038756
# 4    0.756773  0.205406  0.068344  0.306011  0.999551
# ..        ...       ...       ...       ...       ...
# 324  0.664113  0.035204  0.833157  0.929521  0.846454
# 325  0.198674  0.203641  0.557468  0.881899  0.834880
# 326  0.677835  0.595904  0.714058  0.924543  0.726290
# 327  0.110356  0.581724  0.695204  0.866148  0.096121
# 328  0.267216  0.084413  0.101101  0.054931  0.710550
#
# [329 rows x 5 columns]

# %%
# check the ceil value is null or not
newfd = pd.DataFrame(np.random.rand(334,5),index=np.arange(334))
newfd.columns = list('ABCDE')
newfd['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 329    False
# 330    False
# 331    False
# 332    False
# 333    False
# Name: B, Length: 334, dtype: bool

# %%
# conver into none
newfd = pd.DataFrame(np.random.rand(334,5),index=np.arange(334))
newfd.columns = list('ABCDE')
newfd['B'] = None
newfd
# Out:
#             A     B         C         D         E
# 0    0.790626  None  0.541828  0.039221  0.115851
# 1    0.841141  None  0.993834  0.419913  0.247718
# 2    0.228825  None  0.193908  0.030315  0.347194
# 3    0.579327  None  0.164640  0.163917  0.086343
# 4    0.171355  None  0.259489  0.262513  0.563989
# ..        ...   ...       ...       ...       ...
# 329  0.755201  None  0.746726  0.669776  0.868465
# 330  0.282949  None  0.431615  0.957683  0.458196
# 331  0.890149  None  0.987813  0.027754  0.448401
# 332  0.949772  None  0.024497  0.253442  0.653318
# 333  0.053873  None  0.490898  0.946851  0.563189
#
# [334 rows x 5 columns]

# %%
# check none or not
newfd = pd.DataFrame(np.random.rand(334,5),index=np.arange(334))
newfd.columns = list('ABCDE')
newfd['B'] = None
newfd['B'].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 329    True
# 330    True
# 331    True
# 332    True
# 333    True
# Name: B, Length: 334, dtype: bool

# %%
# change the value
newfd = pd.DataFrame(np.random.rand(334,5),index=np.arange(334))
newfd.columns = list('ABCDE')
newfd.loc[:,['B']] = None
newfd
# Out:
#             A     B         C         D         E
# 0    0.735835  None  0.900100  0.254438  0.577076
# 1    0.221755  None  0.361294  0.582339  0.261187
# 2    0.656988  None  0.380230  0.572411  0.680976
# 3    0.528320  None  0.725149  0.006534  0.760128
# 4    0.266858  None  0.344863  0.169486  0.284847
# ..        ...   ...       ...       ...       ...
# 329  0.931981  None  0.656521  0.741139  0.016609
# 330  0.050080  None  0.057755  0.545936  0.357729
# 331  0.439749  None  0.566962  0.230670  0.486426
# 332  0.856773  None  0.809185  0.601184  0.392828
# 333  0.730222  None  0.876958  0.400886  0.335699
#
# [334 rows x 5 columns]

# %%
# change the value
newfd = pd.DataFrame(np.random.rand(334,5),index=np.arange(334))
newfd.columns = list('ABCDE')
newfd.loc[:,['B']] = 56
newfd
# Out:
#             A     B         C         D         E
# 0    0.320029  56.0  0.056912  0.100496  0.976941
# 1    0.194081  56.0  0.452336  0.179141  0.822935
# 2    0.785068  56.0  0.408342  0.125778  0.051439
# 3    0.854797  56.0  0.624790  0.484703  0.237120
# 4    0.875749  56.0  0.324121  0.098077  0.232874
# ..        ...   ...       ...       ...       ...
# 329  0.863996  56.0  0.663800  0.064938  0.053319
# 330  0.970855  56.0  0.566919  0.585647  0.589203
# 331  0.860411  56.0  0.155063  0.853066  0.814900
# 332  0.593766  56.0  0.043294  0.835334  0.946379
# 333  0.290517  56.0  0.129263  0.762600  0.156270
#
# [334 rows x 5 columns]

# %%
df = pd.DataFrame({'name':['Alfred','Batman','Catwomen'],'toy' : [np.nan,'Batmobile','Bullwhip'],'born': [pd.NaT, pd.Timestamp('1940-04-25'),pd.NaT]})
df.head()
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwomen   Bullwhip        NaT

# %%
df = pd.DataFrame({'name':['Alfred','Batman','Catwomen'],'toy' : [np.nan,np.nan,np.nan],'born': [pd.NaT, pd.Timestamp('1940-04-25'),pd.NaT]})
df.dropna(how='all')
# Out:
#        name  toy       born
# 0    Alfred  NaN        NaT
# 1    Batman  NaN 1940-04-25
# 2  Catwomen  NaN        NaT

# %%
df = pd.DataFrame({'name':['Alfred','Batman','Catwomen'],'toy' : [np.nan,np.nan,np.nan],'born': [pd.NaT, pd.Timestamp('1940-04-25'),pd.NaT]})
df.dropna(how='all',axis=1)
# Out:
#        name       born
# 0    Alfred        NaT
# 1    Batman 1940-04-25
# 2  Catwomen        NaT

# %%
# duplicate remove value
df = pd.DataFrame({'name':['Alfred','Batman','Alfred'],'toy' : [np.nan,np.nan,np.nan],'born': [pd.NaT, pd.Timestamp('1940-04-25'),pd.NaT]})
df.drop_duplicates(subset=['name'])
# Out:
#      name  toy       born
# 0  Alfred  NaN        NaT
# 1  Batman  NaN 1940-04-25

# %%
# duplicate remove value
# with keeping value
df = pd.DataFrame({'name':['Alfred','Batman','Alfred'],'toy' : [np.nan,'Batmobile','Bullwhip'],'born': [pd.NaT, pd.Timestamp('1940-04-25'),pd.NaT]})
df.drop_duplicates(subset=['name'],keep='first')
# Out:
#      name        toy       born
# 0  Alfred        NaN        NaT
# 1  Batman  Batmobile 1940-04-25

# %%
# duplicate remove value
# with keeping value
df = pd.DataFrame({'name':['Alfred','Batman','Alfred'],'toy' : [np.nan,'Batmobile','Bullwhip'],'born': [pd.NaT, pd.Timestamp('1940-04-25'),pd.NaT]})
df.drop_duplicates(subset=['name'],keep='last')
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25
# 2  Alfred   Bullwhip        NaT

# %%
# duplicate remove value
# with keeping value
df = pd.DataFrame({'name':['Alfred','Batman','Alfred'],'toy' : [np.nan,'Batmobile','Bullwhip'],'born': [pd.NaT, pd.Timestamp('1940-04-25'),pd.NaT]})
df.drop_duplicates(subset=['name'],keep=False,)
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
# shape
df = pd.DataFrame({'name':['Alfred','Batman','Alfred'],'toy' : [np.nan,'Batmobile','Bullwhip'],'born': [pd.NaT, pd.Timestamp('1940-04-25'),pd.NaT]})
df.shape
# Out:
# (3, 3)

# %%
# shape
df = pd.DataFrame({'name':['Alfred','Batman','Alfred'],'toy' : [np.nan,'Batmobile','Bullwhip'],'born': [pd.NaT, pd.Timestamp('1940-04-25'),pd.NaT]})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   toy     2 non-null      object
#  2   born    1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 200.0+ bytes

# %%
df = pd.DataFrame({'name':['Alfred','Batman','Alfred'],'toy' : [np.nan,'Batmobile','Bullwhip'],'born': [pd.NaT, pd.Timestamp('1940-04-25'),pd.NaT]})
df['name'].value_counts(dropna=False)
# Out:
# name
# Alfred    2
# Batman    1
# Name: count, dtype: int64

# %%
df = pd.DataFrame({'name':['Alfred','Batman','Alfred'],'toy' : [np.nan,'Batmobile','Bullwhip'],'born': [pd.NaT, pd.Timestamp('1940-04-25'),pd.NaT]})
df['toy'].value_counts(dropna=False)
# Out:
# toy
# NaN          1
# Batmobile    1
# Bullwhip     1
# Name: count, dtype: int64

# %%
df = pd.DataFrame({'name':['Alfred','Batman','Alfred'],'toy' : [np.nan,'Batmobile','Bullwhip'],'born': [pd.NaT, pd.Timestamp('1940-04-25'),pd.NaT]})
df.isnull()
# Out:
#     name    toy   born
# 0  False   True   True
# 1  False  False  False
# 2  False  False   True

# %%
df = pd.DataFrame({'name':['Alfred','Batman','Alfred'],'toy' : [np.nan,'Batmobile','Bullwhip'],'born': [pd.NaT, pd.Timestamp('1940-04-25'),pd.NaT]})
df.notnull
# Out:
# <bound method DataFrame.notnull of      name        toy       born
# 0  Alfred        NaN        NaT
# 1  Batman  Batmobile 1940-04-25
# 2  Alfred   Bullwhip        NaT>

# %%
data = pd.read_csv('data1.csv')
data
# Out:
#    Unnamed: 0  Train No  Speed        city
# 0           0     12322     50      rampur
# 1           1     12534    123     kolkata
# 2           2    125654     67    bareilly
# 3           3    564523     87  antarctica
